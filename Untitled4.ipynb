# %%
import pandas as pd
names = pd.read_csv('C:\\Users\\kmobolade\\Documents\\names.csv')

# %%
names
# Out:
#         Unnamed: 0      names sex  births  year
# 0                0       Mary   F    7065  1880
# 1                1       Anna   F    2604  1880
# 2                2       Emma   F    2003  1880
# 3                3  Elizabeth   F    1939  1880
# 4                4     Minnie   F    1746  1880
# 5                5   Margaret   F    1578  1880
# 6                6        Ida   F    1472  1880
# 7                7      Alice   F    1414  1880
# 8                8     Bertha   F    1320  1880
# 9                9      Sarah   F    1288  1880
# 10              10      Annie   F    1258  1880
# 11              11      Clara   F    1226  1880
# 12              12       Ella   F    1156  1880
# 13              13   Florence   F    1063  1880
# 14              14       Cora   F    1045  1880
# 15              15     Martha   F    1040  1880
# 16              16      Laura   F    1012  1880
# 17              17     Nellie   F     995  1880
# 18              18      Grace   F     982  1880
# 19              19     Carrie   F     949  1880
# 20              20      Maude   F     858  1880
# 21              21      Mabel   F     808  1880
# 22              22     Bessie   F     796  1880
# 23              23     Jennie   F     793  1880
# 24              24   Gertrude   F     787  1880
# 25              25      Julia   F     783  1880
# 26              26     Hattie   F     769  1880
# 27              27      Edith   F     768  1880
# 28              28     Mattie   F     704  1880
# 29              29       Rose   F     700  1880
# ...            ...        ...  ..     ...   ...
# 483858      483858     Janyce   F      66  1952
# 483859      483859     Johnny   F      66  1952
# 483860      483860    Kenneth   F      66  1952
# 483861      483861       Lani   F      66  1952
# 483862      483862    Lindsey   F      66  1952
# 483863      483863    Lisbeth   F      66  1952
# 483864      483864       Lura   F      66  1952
# 483865      483865  Thomasina   F      66  1952
# 483866      483866  Annamarie   F      65  1952
# 483867      483867    Babette   F      65  1952
# 483868      483868   Carletta   F      65  1952
# 483869      483869   Drucilla   F      65  1952
# 483870      483870       Iola   F      65  1952
# 483871      483871       Nena   F      65  1952
# 483872      483872      Tresa   F      65  1952
# 483873      483873     Allene   F      64  1952
# 483874      483874    Aurelia   F      64  1952
# 483875      483875     Fredia   F      64  1952
# 483876      483876      Kandy   F      64  1952
# 483877      483877       Kari   F      64  1952
# 483878      483878      Londa   F      64  1952
# 483879      483879      Merri   F      64  1952
# 483880      483880   Merrilee   F      64  1952
# 483881      483881     Myrtis   F      64  1952
# 483882      483882   Prudence   F      64  1952
# 483883      483883     Vonnie   F      64  1952
# 483884      483884      Wendi   F      64  1952
# 483885      483885    Deloise   F      63  1952
# 483886      483886   Isabella   F      63  1952
# 483887      483887  Kimberlee   F      63     1
#
# [483888 rows x 5 columns]

# %%
df = names.head().copy()
df.index = df['names']
del df['names']
df
# Out:
#            Unnamed: 0 sex  births  year
# names
# Mary                0   F    7065  1880
# Anna                1   F    2604  1880
# Emma                2   F    2003  1880
# Elizabeth           3   F    1939  1880
# Minnie              4   F    1746  1880

# %%
names
# Out:
#         Unnamed: 0      names sex  births  year
# 0                0       Mary   F    7065  1880
# 1                1       Anna   F    2604  1880
# 2                2       Emma   F    2003  1880
# 3                3  Elizabeth   F    1939  1880
# 4                4     Minnie   F    1746  1880
# 5                5   Margaret   F    1578  1880
# 6                6        Ida   F    1472  1880
# 7                7      Alice   F    1414  1880
# 8                8     Bertha   F    1320  1880
# 9                9      Sarah   F    1288  1880
# 10              10      Annie   F    1258  1880
# 11              11      Clara   F    1226  1880
# 12              12       Ella   F    1156  1880
# 13              13   Florence   F    1063  1880
# 14              14       Cora   F    1045  1880
# 15              15     Martha   F    1040  1880
# 16              16      Laura   F    1012  1880
# 17              17     Nellie   F     995  1880
# 18              18      Grace   F     982  1880
# 19              19     Carrie   F     949  1880
# 20              20      Maude   F     858  1880
# 21              21      Mabel   F     808  1880
# 22              22     Bessie   F     796  1880
# 23              23     Jennie   F     793  1880
# 24              24   Gertrude   F     787  1880
# 25              25      Julia   F     783  1880
# 26              26     Hattie   F     769  1880
# 27              27      Edith   F     768  1880
# 28              28     Mattie   F     704  1880
# 29              29       Rose   F     700  1880
# ...            ...        ...  ..     ...   ...
# 483858      483858     Janyce   F      66  1952
# 483859      483859     Johnny   F      66  1952
# 483860      483860    Kenneth   F      66  1952
# 483861      483861       Lani   F      66  1952
# 483862      483862    Lindsey   F      66  1952
# 483863      483863    Lisbeth   F      66  1952
# 483864      483864       Lura   F      66  1952
# 483865      483865  Thomasina   F      66  1952
# 483866      483866  Annamarie   F      65  1952
# 483867      483867    Babette   F      65  1952
# 483868      483868   Carletta   F      65  1952
# 483869      483869   Drucilla   F      65  1952
# 483870      483870       Iola   F      65  1952
# 483871      483871       Nena   F      65  1952
# 483872      483872      Tresa   F      65  1952
# 483873      483873     Allene   F      64  1952
# 483874      483874    Aurelia   F      64  1952
# 483875      483875     Fredia   F      64  1952
# 483876      483876      Kandy   F      64  1952
# 483877      483877       Kari   F      64  1952
# 483878      483878      Londa   F      64  1952
# 483879      483879      Merri   F      64  1952
# 483880      483880   Merrilee   F      64  1952
# 483881      483881     Myrtis   F      64  1952
# 483882      483882   Prudence   F      64  1952
# 483883      483883     Vonnie   F      64  1952
# 483884      483884      Wendi   F      64  1952
# 483885      483885    Deloise   F      63  1952
# 483886      483886   Isabella   F      63  1952
# 483887      483887  Kimberlee   F      63     1
#
# [483888 rows x 5 columns]

# %%
print ('.iloc indexing by position')
print(df.iloc[3])
# Out:
# .iloc indexing by position
# Unnamed: 0       3
# sex              F
# births        1939
# year          1880
# Name: Elizabeth, dtype: object

# %%
print('.loc indexing by index')
print(df.loc['Minnie'])
# Out:
# .loc indexing by index
# Unnamed: 0       4
# sex              F
# births        1746
# year          1880
# Name: Minnie, dtype: object

# %%
bool_michael = names['names']== 'Michael'
names[bool_michael].head()
# Out:
#       Unnamed: 0    names sex  births  year
# 987          987  Michael   M     354  1880
# 2991        2991  Michael   M     298  1881
# 5019        5019  Michael   M     321  1882
# 7170        7170  Michael   M     307  1883
# 9368        9368  Michael   M     373  1884

# %%
#& is the symbol for "and"
#| is the symbol for or 
True & False
# Out:
# False

# %%
names[(names['names'] == 'Michael') & (names['sex']=='F')].head()
# Out:
#        Unnamed: 0    names sex  births  year
# 44276       44276  Michael   F       7  1897
# 75251       75251  Michael   F       5  1906
# 86615       86615  Michael   F       7  1909
# 90663       90663  Michael   F       9  1910
# 95687       95687  Michael   F       7  1911

# %%
#Group by and Pivot Table 
total_births_gender = names.pivot_table('births',index = 'year', columns = 'sex', aggfunc = sum)
total_births= names.groupby(['year']).sum()

# %%
total_births_gender.head()
# Out:
# sex        F       M
# year
# 1         63     NaN
# 1880   90993  110491
# 1881   91954  100745
# 1882  107850  113688
# 1883  112321  104629

# %%
#Merge is equivalent to join in SQL
births = pd.merge(total_births, total_births_gender, how ='inner', left_index = True, right_index=True)

# %%
births.plot(title = 'Total births by sex and year')

# %%
males = names[names['sex'] == 'M']
total_male_births = males.groupby('year').sum()
michael = names[(names['names'] == 'Michael') & (names['sex'] == 'M')].groupby('year').sum()
total_michael = pd.merge(total_male_births, pd.DataFrame(michael), how= 'left', left_index=True, right_index=True)

# %%
names.head()
# Out:
#    Unnamed: 0      names sex  births  year
# 0           0       Mary   F    7065  1880
# 1           1       Anna   F    2604  1880
# 2           2       Emma   F    2003  1880
# 3           3  Elizabeth   F    1939  1880
# 4           4     Minnie   F    1746  1880

# %%
total_michael.head()
# Out:
#       Unnamed: 0_x  births_x  Unnamed: 0_y  births_y
# year
# 1880       1555789    110491           987       354
# 1881       3425692    100745          2991       298
# 1882       6057688    113688          5019       321
# 1883       7859415    104629          7170       307
# 1884      11115000    114445          9368       373

# %%
total_michael.columns = ['total_births', 'michael_births']
total_michael['percent'] = total_michael['michael_births']/total_michael['total_births']
total_michael.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-366434ab0ce2> in <module>()
# ----> 1 total_michael.columns = ['total_births', 'michael_births']
#       2 total_michael['percent'] = total_michael['michael_births']/total_michael['total_births']
#       3 total_michael.head()
#
# C:\Users\kmobolade\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\generic.pyc in __setattr__(self, name, value)
#    2159         try:
#    2160             object.__getattribute__(self, name)
# -> 2161             return object.__setattr__(self, name, value)
#    2162         except AttributeError:
#    2163             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:42548)()
#
# C:\Users\kmobolade\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\generic.pyc in _set_axis(self, axis, labels)
#     411
#     412     def _set_axis(self, axis, labels):
# --> 413         self._data.set_axis(axis, labels)
#     414         self._clear_item_cache()
#     415
#
# C:\Users\kmobolade\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\internals.pyc in set_axis(self, axis, new_labels)
#    2217         if new_len != old_len:
#    2218             raise ValueError('Length mismatch: Expected axis has %d elements, '
# -> 2219                              'new values have %d elements' % (old_len, new_len))
#    2220
#    2221         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 2 elements

# %%
from sklearn import datasets
iris = datasets.load_iris()
#Creating from sklearn bunch
iris_df = pd.DataFrame.from_records(iris.data)

# %%
iris_df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2
