# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
adv = pd.read_csv('C:\\Users\\kmobolade\\Desktop\\advertising.csv')
from sklearn import neighbors

# %%
np.random.seed(0)

x = np.sort(15* np.random.rand(80,1),axis = 0)
T = np.linspace(0,15,1000)[:,np.newaxis]
y = np.sin(x).ravel()

#Add noise to targets

y += 1 * (0.5 - np.random.rand(80))
plt.scatter(x,y)

# %%
adv = pd.read_csv('C:\\Users\\kmobolade\\Desktop\\advertising.csv')
tv = adv['TV']
radio = adv['Radio']
news = adv['Newspaper']
y = adv['Sales']

# %%
knn = neighbors.KNeighborsRegressor(n_neighbors =1)
y2 = knn.fit(tv.reshape(len(adv),1),y).predict(tv.reshape(len(adv),1))

plt.scatter(tv,y,c = 'k',label ='data')
plt.plot(tv,y2, c ='g', label = 'prediction')

# %%
knn = neighbors.KNeighborsRegressor(n_neighbors =1)
y2 = knn.fit(tv.reshape(len(adv),1),y).predict(tv.reshape(len(adv),1))

plt.scatter(tv,y,c = 'k',label ='data')
plt.plot(tv,y2, c ='g', label = 'prediction')
tmp = adv.sort(columns = 'TV')

# %%
tmp = adv.sort(columns ='TV')

# %%
tmp.head()# sorting columns
# Out:
#      Unnamed: 0   TV  Radio  Newspaper  Sales
# 130         131  0.7   39.6        8.7    1.6
# 155         156  4.1   11.6        5.7    3.2
# 78           79  5.4   29.9        9.4    5.3
# 56           57  7.3   28.1       41.4    5.5
# 126         127  7.8   38.9       50.6    6.6
